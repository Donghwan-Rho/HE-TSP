# %%
# Figure 6
# wikitext-103-v1
# Please introduce yourself.
import matplotlib.pyplot as plt
import numpy as np

x_labels = [0, 20, 40, 60, 80, 100]

#                                      0      20      40      60      80     100
s2_NIC_not_pp_corruption_score = [1.5433, 1.4033, 1.2133, 0.6500, 0.7267, 0.8500]
s2_NIC_pp_corruption_score     = [1.1867, 1.0733, 0.9067, 0.4967, 0.5900, 0.6567]
s2_IC_not_pp_corruption_score  = [1.2800, 1.0133, 1.0567, 0.6567, 0.5300, 0.5367]
s2_IC_pp_corruption_score      = [0.8967, 0.8433, 0.7600, 0.4548, 0.4967, 0.5900]
base_corruption_score          = [0.6367, 0.8267, 0.5833, 0.4700, 0.4367, 0.4667]
#                                     0     20     40     60     80,   100
s2_NIC_not_pp_corruption_ratio = [19.00, 12.00,  8.00,  0.67,  2.33,  2.00]
s2_NIC_pp_corruption_ratio     = [12.00,  8.33,  5.33,  0.33,  1.00,  0.67]
s2_IC_not_pp_corruption_ratio  = [10.33,  6.33,  6.33,  2.00,  0.67,  1.00]
s2_IC_pp_corruption_ratio      = [ 8.33,  6.33,  3.00,  0.33,  0.33,  0.00]
base_corruption_ratio          = [ 0,  0,  0,  0,  0,  0]

selected_steps = [0, 20, 40, 60, 80, 100]

selected_indices = [x_labels.index(step) for step in selected_steps]

def filter_data(data):
    return [data[i] for i in selected_indices]

x_positions = np.arange(len(selected_steps))

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].plot(x_positions, filter_data(s2_NIC_not_pp_corruption_score), marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[0].plot(x_positions, filter_data(s2_NIC_pp_corruption_score), marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[0].plot(x_positions, filter_data(s2_IC_not_pp_corruption_score), marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[0].plot(x_positions, filter_data(s2_IC_pp_corruption_score), marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[0].plot(x_positions, filter_data(base_corruption_score), marker='o', linestyle=(0, (3, 5)), color='blue', label='Baseline')
axs[0].set_title('Corruption Score', fontsize=20)
axs[0].set_xticks(x_positions)
axs[0].set_xticklabels(selected_steps)
axs[0].set_xlabel('Fine-tuning Step')
axs[0].set_ylabel('Corruption Score')
axs[0].legend(loc='upper right', fontsize=14)

axs[1].plot(x_positions, filter_data(s2_NIC_not_pp_corruption_ratio), marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[1].plot(x_positions, filter_data(s2_NIC_pp_corruption_ratio), marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[1].plot(x_positions, filter_data(s2_IC_not_pp_corruption_ratio), marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[1].plot(x_positions, filter_data(s2_IC_pp_corruption_ratio), marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[1].plot(x_positions, filter_data(base_corruption_ratio), marker='o', linestyle=(0, (3, 5)), color='blue', label='Baseline')
axs[1].set_title('Corruption Ratio', fontsize=20)
axs[1].set_xticks(x_positions)
axs[1].set_xticklabels(selected_steps)
axs[1].set_xlabel('Fine-tuning Step')
axs[1].set_ylabel('Corruption Ratio (%)')
axs[1].legend(loc='upper right', fontsize=14)

plt.tight_layout()
plt.show()

# %%
# Figure 11
# wikitext-103-v1
# Tell me about a time you overcame a challenge.
import matplotlib.pyplot as plt
import numpy as np

x_labels = [0, 20, 40, 60, 80, 100]

#                                      0      20      40      60      80     100
s2_NIC_not_pp_corruption_score = [2.0100, 1.6967, 1.5733, 0.8433, 0.7100, 0.8900]
s2_NIC_pp_corruption_score =     [1.1867, 1.3467, 1.2100, 0.6533, 0.6933, 0.6600]
s2_IC_not_pp_corruption_score =  [1.2900, 1.4933, 1.0933, 0.8600, 0.7200, 0.5800]
s2_IC_pp_corruption_score =      [1.2200, 1.1467, 1.0867, 0.5733, 0.6067, 0.6200]
base_corruption_score          = [0.7400, 0.9967, 0.7733, 0.5700, 0.5467, 0.4567]
#                                     0     20     40     60     80,   100
s2_NIC_not_pp_corruption_ratio = [19.00, 12.33, 11.00,  1.33,  2.00,  0.33]
s2_NIC_pp_corruption_ratio =     [ 7.67,  6.33,  5.33,  0.67,  1.67,  1.67]
s2_IC_not_pp_corruption_ratio =  [ 8.33, 13.67,  4.67,  1.33,  1.33,  0.33]
s2_IC_pp_corruption_ratio =      [ 6.67,  6.67,  2.67,  0.33,  0.33,  0.33]
base_corruption_ratio          = [ 0,  0,  0,  0,  0,  0]

npp_nic_zero_probability_ratio = [1-0.3112592547, 1-0.3000502745, 1-0.2868122601, 1-0.2477254523, 1-0.2430223898, 1-0.248890994]
pp_nic_zero_probability_ratio  = [1-0.2771543, 1-0.2886407278, 1-0.2764092436, 1-0.2445417261, 1-0.2360069808, 1-0.2395016522]
npp_ic_zero_probability_ratio  = [1-0.2789959007, 1-0.2814207843, 1-0.2733902667, 1-0.2529332704, 1-0.2389699596, 1-0.2386333951]
pp_ic_zero_probability_ratio   = [1-0.2834292956, 1-0.2812858195, 1-0.2793583909, 1-0.2352660038, 1-0.2375961868, 1-0.2415336767]
baseline_zero_probability_ratio = [1-0.2546368565, 1-0.2659063041, 1-0.2563382466, 1-0.2392939253, 1-0.2374374206, 1-0.2264427305]

x_positions = np.arange(len(x_labels))

fig, axs = plt.subplots(1, 3, figsize=(18, 5))

axs[0].plot(x_positions, npp_nic_zero_probability_ratio, marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[0].plot(x_positions, pp_nic_zero_probability_ratio, marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[0].plot(x_positions, npp_ic_zero_probability_ratio, marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[0].plot(x_positions, pp_ic_zero_probability_ratio, marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[0].plot(x_positions, baseline_zero_probability_ratio, label="Baseline", linestyle=(0, (3, 5)), marker='o', markersize=8, color='blue')
axs[0].set_title('Fine-tuning Steps vs. Zero Probability Ratio')
axs[0].set_xticks(x_positions)
axs[0].set_xticklabels(x_labels)
axs[0].set_xlabel('Fine-tuning Step')
axs[0].set_title("Zero Probability Ratio", fontsize=20)
axs[0].legend(loc='upper left', fontsize=14)
axs[0].set_ylim(0.68, 0.795)

axs[1].plot(x_positions, s2_NIC_not_pp_corruption_score, marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[1].plot(x_positions, s2_NIC_pp_corruption_score, marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[1].plot(x_positions, s2_IC_not_pp_corruption_score, marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[1].plot(x_positions, s2_IC_pp_corruption_score, marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[1].plot(x_positions, filter_data(base_corruption_score), marker='o', linestyle=(0, (3, 5)), color='blue', label='Baseline')
axs[1].set_title('Corruption Score', fontsize=20)
axs[1].set_xticks(x_positions)
axs[1].set_xticklabels(x_labels)
axs[1].set_xlabel('Fine-tuning Step')
axs[1].set_ylabel('Corruption Score')
axs[1].legend(loc='upper right', fontsize=14)

axs[2].plot(x_positions, s2_NIC_not_pp_corruption_ratio, marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[2].plot(x_positions, s2_NIC_pp_corruption_ratio, marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[2].plot(x_positions, s2_IC_not_pp_corruption_ratio, marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[2].plot(x_positions, s2_IC_pp_corruption_ratio, marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[2].plot(x_positions, filter_data(base_corruption_ratio), marker='o', linestyle=(0, (3, 5)), color='blue', label='Baseline')
axs[2].set_title('Corruption Ratio', fontsize=20)
axs[2].set_xticks(x_positions)
axs[2].set_xticklabels(x_labels)
axs[2].set_xlabel('Fine-tuning Step')
axs[2].set_ylabel('Corruption Ratio (%)')
axs[2].legend(loc='upper right', fontsize=14)

plt.tight_layout()
plt.show()

# %%
# Figure 12
# wikitext-103-v1
# Describe the U.S. high school math curriculum.
import matplotlib.pyplot as plt
import numpy as np

x_labels = [0, 20, 40, 60, 80, 100]

#                                      0      20      40      60      80     100
s2_NIC_not_pp_corruption_score = [2.0267, 1.8067, 1.4400, 0.7833, 0.8467, 0.8733]
s2_NIC_pp_corruption_score     = [1.3633, 1.2933, 1.0233, 0.9567, 0.7533, 0.7300]
s2_IC_not_pp_corruption_score  = [1.4967, 1.3867, 1.3033, 0.7867, 0.8200, 0.8967]
s2_IC_pp_corruption_score      = [1.1433, 1.2600, 1.1067, 0.7200, 0.6367, 0.8000]
base_corruption_score          = [0.9067, 0.9367, 0.8533, 0.6867, 0.6633, 0.5700]
#                                     0     20     40     60     80,   100
s2_NIC_not_pp_corruption_ratio = [23.00, 15.67,  7.33,  1.00,  2.00,  2.00]
s2_NIC_pp_corruption_ratio     = [ 8.33,  7.67,  2.67,  1.67,  1.00,  1.33]
s2_IC_not_pp_corruption_ratio  = [13.33,  8.00,  7.00,  2.33,  1.00,  2.67]
s2_IC_pp_corruption_ratio      = [ 5.67,  3.67,  3.67,  1.67,  1.00,  0.33]
base_corruption_ratio          = [ 0,  0,  0,  0,  0,  0]

npp_nic_zero_probability_ratio  = [1-0.306008466, 1-0.3171016907, 1-0.3146966876, 1-0.2825188476, 1-0.2751855465, 1-0.2783615413]
pp_nic_zero_probability_ratio   = [1-0.3020010832, 1-0.3012899489, 1-0.3030941352, 1-0.2728646228, 1-0.2746761391, 1-0.2734202616]
npp_ic_zero_probability_ratio   = [1-0.3028743047, 1-0.3004236623, 1-0.3013714407, 1-0.2708172186, 1-0.2699824372, 1-0.2714265295]
pp_ic_zero_probability_ratio    = [1-0.285721772, 1-0.3088207167, 1-0.3062620648, 1-0.2665218562, 1-0.2734243118, 1-0.2694635522]
baseline_zero_probability_ratio = [1-0.2919302147, 1-0.2847963948, 1-0.2906018647, 1-0.2741437521, 1-0.2604627148, 1-0.2559768544]

x_positions = np.arange(len(x_labels))

fig, axs = plt.subplots(1, 3, figsize=(18, 5))

axs[0].plot(x_positions, npp_nic_zero_probability_ratio, marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[0].plot(x_positions, pp_nic_zero_probability_ratio, marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[0].plot(x_positions, npp_ic_zero_probability_ratio, marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[0].plot(x_positions, pp_ic_zero_probability_ratio, marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[0].plot(x_positions, baseline_zero_probability_ratio, label="Baseline", linestyle=(0, (3, 5)), marker='o', markersize=8, color='blue')
axs[0].set_title("Zero Probability Ratio", fontsize=20)
axs[0].set_xticks(x_positions)
axs[0].set_xticklabels(x_labels)
axs[0].set_xlabel('Fine-tuning Step')
axs[0].set_title("Zero Probability Ratio", fontsize=20)
axs[0].legend(loc='upper left', fontsize=14)
axs[0].set_ylim(0.67, 0.75)

axs[1].plot(x_positions, s2_NIC_not_pp_corruption_score, marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[1].plot(x_positions, s2_NIC_pp_corruption_score, marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[1].plot(x_positions, s2_IC_not_pp_corruption_score, marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[1].plot(x_positions, s2_IC_pp_corruption_score, marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[1].plot(x_positions, filter_data(base_corruption_score), marker='o', linestyle=(0, (3, 5)), color='blue', label='Baseline')
axs[1].set_title('Corruption Score', fontsize=20)
axs[1].set_xticks(x_positions)
axs[1].set_xticklabels(x_labels)
axs[1].set_xlabel('Fine-tuning Step')
axs[1].set_ylabel('Corruption Score')
axs[1].legend(loc='upper right', fontsize=14)

axs[2].plot(x_positions, s2_NIC_not_pp_corruption_ratio, marker='o', linestyle='-', color='#E69F00', label='w/o TSP, w/o PP')
axs[2].plot(x_positions, s2_NIC_pp_corruption_ratio, marker='o', linestyle='-', color='#B8E186', label='w/o TSP, w/ PP')
axs[2].plot(x_positions, s2_IC_not_pp_corruption_ratio, marker='o', linestyle='-', color='#7FBF7F', label='w/ TSP, w/o PP')
axs[2].plot(x_positions, s2_IC_pp_corruption_ratio, marker='o', linestyle='-', color='#BA55D3', label='w/ TSP, w/ PP')
axs[2].plot(x_positions, filter_data(base_corruption_ratio), marker='o', linestyle=(0, (3, 5)), color='blue', label='Baseline')
axs[2].set_title('Corruption Ratio', fontsize=20)
axs[2].set_xticks(x_positions)
axs[2].set_xticklabels(x_labels)
axs[2].set_xlabel('Fine-tuning Step')
axs[2].set_ylabel('Corruption Ratio (%)')
axs[2].legend(loc='upper right', fontsize=14)

plt.tight_layout()
plt.show()
